# %%
import numpy as np
import matplotlib.pyplot as plt
import ImageManipulation as IM
import os
from importlib import reload

# %%
np.genfromtxt?

# %%
wdir = r'N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all'
relpath = r'cell_analysis\cell_heterogeneities.csv'
fname = os.path.join(wdir, fname)
celldat = np.genfromtxt(fname, skip_header = 1, delimiter = ',', dtype = None)
# Out:
# C:\Users\voort\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   after removing the cwd from sys.path.

# %%
Donlycols = np.arange(0,3)
batch1cols = np.arange(3,20)
batch2cols = np.arange(20,42)
batch3cols = np.arange(42,62)

# %%
celldat['f0'][batch1cols]
# Out:
# array([b'CD95_DDD_batch1-L2', b'CD95_DDD_batch1-L3',
#        b'CD95_DDD_batch1+L5', b'CD95_DDD_batch1+L6',
#        b'CD95_DDD_batch1+L7', b'CD95_DDD_batch1+L8',
#        b'CD95_DDD_batch1+L8-2', b'CD95_DDD_batch1+L9',
#        b'CD95_DDD_batch1+L10', b'CD95_DDD_batch1+L11',
#        b'CD95_DDD_batch1+L12', b'CD95_DDD_batch1+L13',
#        b'CD95_DDD_batch1+L14', b'CD95_DDD_batch1+L15',
#        b'CD95_DDD_batch1+L16', b'CD95_DDD_batch1+L17',
#        b'CD95_DDD_batch1+L18'], dtype='|S20')

# %%
plt.plot(celldat['f1'][Donlycols], celldat['f2'][Donlycols], 'om', label = ' Donor Only')
plt.plot(celldat['f1'][batch1cols], celldat['f2'][batch1cols], '*b', label = 'batch 1 (29 Okt)*')
#add secondary population
plt.plot(celldat['f1'][batch1cols], celldat['f5'][batch1cols], '*b')
plt.plot(celldat['f1'][batch2cols], celldat['f2'][batch2cols], '*r', label = 'batch 2 (15 Nov)')
#add secondary population
plt.plot(celldat['f1'][batch2cols], celldat['f5'][batch2cols], '*r')
plt.plot(celldat['f1'][batch3cols], celldat['f2'][batch3cols], '*g', label = 'batch 3 (15 Nov)')
#add secondary population
plt.plot(celldat['f1'][batch3cols], celldat['f5'][batch3cols], '*g')

plt.xlim([-10,125])
plt.ylim([1.75,2.5])
plt.xlabel('time [min]', fontsize = 16)
plt.ylabel('lifetime [ns]', fontsize = 16)
plt.text(20,1.8,'*this measurement had some issues')
plt.legend(fontsize = 12, loc = [1, 0.6])
plt.savefig('20191126_HeteroFRET_t_vs_tau.png', dpi = 300, bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(celldat['f1'][Donlycols], celldat['f3'][Donlycols], 'om', label = ' Donor Only')
plt.plot(celldat['f1'][batch1cols], celldat['f3'][batch1cols], '*b', label = 'batch 1 (29 Okt)*')
#add secondary population
plt.plot(celldat['f1'][batch1cols], celldat['f6'][batch1cols], '*b')
plt.plot(celldat['f1'][batch2cols], celldat['f3'][batch2cols], '*r', label = 'batch 2 (15 Nov)')
#add secondary population
plt.plot(celldat['f1'][batch2cols], celldat['f6'][batch2cols], '*r')
plt.plot(celldat['f1'][batch3cols], celldat['f3'][batch3cols], '*g', label = 'batch 3 (15 Nov)')
#add secondary population
plt.plot(celldat['f1'][batch3cols], celldat['f6'][batch3cols], '*g')

plt.xlim([-10,125])
plt.ylim([0,0.4])
plt.xlabel('time [min]', fontsize = 16)
plt.ylabel('Efficiency\'', fontsize = 16)
plt.text(10,0.02,'*this measurement had some issues')
plt.legend(fontsize = 12, loc = [1, 0.6])
plt.savefig('20191126_HeteroFRET_t_vs_E.png', dpi = 300, bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
def EvsTau(tau, tau0):
    return 1 - tau/tau0

# %%
#plt.plot(celldat['f2'][Donlycols], celldat['f3'][Donlycols], 'om', label = ' Donor Only')
plt.plot(celldat['f2'][batch1cols], celldat['f3'][batch1cols], '*b', label = 'batch 1 (29 Okt)*')
#add secondary population
plt.plot(celldat['f5'][batch1cols], celldat['f6'][batch1cols], '*b')
plt.plot(celldat['f2'][batch2cols], celldat['f3'][batch2cols], '*r', label = 'batch 2 (15 Nov)')
#add secondary population
plt.plot(celldat['f5'][batch2cols], celldat['f6'][batch2cols], '*r')
plt.plot(celldat['f2'][batch3cols], celldat['f3'][batch3cols], '*g', label = 'batch 3 (15 Nov)')
#add secondary population
plt.plot(celldat['f5'][batch3cols], celldat['f6'][batch3cols], '*g')

#plt theoretical efficiency
tau = np.linspace(1.8, 2.44, 100)
tau0 = 2.44
E = EvsTau(tau, tau0)
plt.plot(tau, E, '-', label = 'theoretical \u03C4 D(0) = 2.44 ns')

#plt.xlim([-10,125])
#plt.ylim([0,0.4])
plt.xlabel('lifetime [ns]', fontsize = 16)
plt.ylabel('Efficiency\' [ns]', fontsize = 16)
plt.text(1.8,0.02,'*this measurement had some issues')
plt.legend(fontsize = 12, loc = [1, 0.7])
plt.savefig('20191126_HeteroFRET_E_vs_tau.png', dpi = 300, bbox_inches = 'tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # exporting 1024 TACS from data

# %%
reload (IM)
# Out:
# <module 'ImageManipulation' from 'K:\\vanderVoortN\\FRC\\Code\\ImageManipulation.py'>

# %%
wdir = r'N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all'
outdir = r'N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\chisurf'

files = os.listdir(wdir)

for file in files:
    print(file[-4:])
    if file[-4:] != '.ptu':
        continue
    fname = os.path.join(wdir, file)
    print(fname)
    data = IM.processLifetimeImage(fname.encode(), uselines = np.array([1]), Gchan = np.array([0,1]), 
                                   Rchan = np.array([4,5]), 
                                   Ychan = np.array([4,5]), ntacs = 1024, TAC_range = 4096, \
                                   pulsetime = 50e-9, dwelltime = 1e-5)
    data.loadLifetime()
    GTACS = np.stack((np.arange(1024), data.getTACS(mode = 'G'))).transpose()
    data.gate(0,440)
    RTACS = np.stack((np.arange(1024), data.getTACS(mode = 'R'))).transpose()
    data.loadLifetime()
    data.gate(440,800)
    YTACS = np.stack((np.arange(1024), data.getTACS(mode = 'R'))).transpose()
    np.savetxt(os.path.join(outdir, file[:-4] + '_G.dat'), GTACS, fmt = '%i')
    np.savetxt(os.path.join(outdir, file[:-4] + '_R.dat'), RTACS, fmt = '%i')
    np.savetxt(os.path.join(outdir, file[:-4] + '_Y.dat'), YTACS, fmt = '%i')
# Out:
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L1.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L1.txt'
# number of records is 1222223
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L10.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L10.txt'
# number of records is 8422704
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L11.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L11.txt'
# number of records is 21954382
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L12.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L12.txt'
# number of records is 18114163
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L13.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L13.txt'
# number of records is 16774497
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L14.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L14.txt'
# number of records is 8718592
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L15.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L15.txt'
# number of records is 6205580
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L16.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L16.txt'
# number of records is 14490636
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L17.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L17.txt'
# number of records is 4389061
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L2.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L2.txt'
# number of records is 9110086
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L3.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L3.txt'
# number of records is 6116117
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L4.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L4.txt'
# number of records is 39146468
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L5.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L5.txt'
# number of records is 2786564
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L6.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L6.txt'
# number of records is 34422629
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L7.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L7.txt'
# number of records is 6859296
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L8.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L8.txt'
# number of records is 83690141
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD+L9.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD+L9.txt'
# number of records is 33357648
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L1.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L1.txt'
# number of records is 3825588
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L10.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L10.txt'
# number of records is 19401326
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L11.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L11.txt'
# number of records is 21543905
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L12.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L12.txt'
# number of records is 82327514
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L13.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L13.txt'
# number of records is 62701450
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L14.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L14.txt'
# number of records is 40943742
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L15.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L15.txt'
# number of records is 28624870
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L16.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L16.txt'
# number of records is 40363434
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L2.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L2.txt'
# number of records is 8174999
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L3.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L3.txt'
# number of records is 2186757
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L4.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L4.txt'
# number of records is 27771589
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L5.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L5.txt'
# number of records is 26219772
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L6.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L6.txt'
# number of records is 72956313
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L7.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L7.txt'
# number of records is 35430571
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L8.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L8.txt'
# number of records is 18188715
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-2+L9.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-2+L9.txt'
# number of records is 57819804
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-21.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-21.txt'
# number of records is 13978884
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-22.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-22.txt'
# number of records is 17754163
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD-23.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD-23.txt'
# number of records is 100454223
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD_1.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD_1.txt'
# number of records is 12217626
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD_2.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD_2.txt'
# number of records is 21839866
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD_3.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD_3.txt'
# number of records is 20483059
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD_4.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD_4.txt'
# number of records is 8590649
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD_5.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD_5.txt'
# number of records is 20715061
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\CD95-DeltaDD_6.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\CD95-DeltaDD_6.txt'
# number of records is 17174069
# dwelltime not found in header, using user-set value
# ysis
# surf
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\Donly1.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\Donly1.txt'
# number of records is 48173087
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\Donly2.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\Donly2.txt'
# number of records is 27763891
# dwelltime not found in header, using user-set value
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\Donly3.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\Donly3.txt'
# number of records is 5252238
# dwelltime not found in header, using user-set value
# ader
# ders
# .ptu
# N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\IRF_mirror1.ptu
# header dir already exists
# b'N:\\Singlem\\singlem19-4\\November\\15_CD95_NB_NV\\all\\header\\IRF_mirror1.txt'
# not all needed variables were found
# number of records is 17367276
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-0371dc6a396d> in <module>
#      13                                    Rchan = np.array([4,5]),
#      14                                    Ychan = np.array([4,5]), ntacs = 1024, TAC_range = 4096, \
# ---> 15                                    pulsetime = 50e-9, dwelltime = 1e-5)
#      16     data.loadLifetime()
#      17     GTACS = np.stack((np.arange(1024), data.getTACS(mode = 'G'))).transpose()
#
# K:\vanderVoortN\FRC\Code\ImageManipulation.py in __init__(self, fname, uselines, Gchan, Rchan, Ychan, ntacs, TAC_range, pulsetime, dwelltime)
#      62             "uselines, Gchan, Ychan and Rchan must be numpy array type!"
#      63         #initialize baseLifetimeObject
# ---> 64         self._makeLifetime(fname, uselines, Gchan, Rchan, Ychan, ntacs, TAC_range, dwelltime)
#      65         #initialize baseIntensityObject
#      66         self._makeIntensity()
#
# K:\vanderVoortN\FRC\Code\ImageManipulation.py in _makeLifetime(self, fname, uselines, Gchan, Rchan, Ychan, ntacs, TAC_range, dwelltime)
#     343         print('number of records is ' + str(NumRecords))
#     344
# --> 345         dimX, dimY, _dwelltime, counttime = cpp_wrappers.read_header(header_name)
#     346         if _dwelltime == -1:
#     347             print('dwelltime not found in header, using user-set value')
#
# K:\vanderVoortN\FRC\Code\cpp_wrappers.py in read_header(header_name)
#      87         dwelltime = -1
#      88     try:
# ---> 89         return dimX, dimY, dwelltime, counttime
#      90     except NameError:
#      91         logger.error("not all needed variables were found")
#
# UnboundLocalError: local variable 'dimX' referenced before assignment

# %%
def epsilon(DAdat, D0dat, bgrange = [350,450], makeplot = True, dtime = 0.064):
    #calc backgrounds
    bgest_DA = np.mean(DAdat[bgrange[0]:bgrange[1],1])
    bgest_D0 = np.mean(D0dat[bgrange[0]:bgrange[1],1])
    #calc epsilon
    eps = (DAdat[:,1] - bgest_DA) / (D0dat[:,1]- bgest_D0) * \
            max(D0dat[:,1]-bgest_D0) / max(DAdat[:,1] - bgest_DA)
    #define time axis
    time = run1_1[:,0] * dtime
    #plot
    if makeplot:
        plt.plot(time, eps)
        ax=plt.gca()
        ax.set_yscale('log')
        plt.plot(np.array([260,260])*dtime,[0,1.1], 'r--')
        plt.plot(np.array([180,180])*dtime,[0,1.1], 'r--')
        plt.ylim(0.1,1.1)
        plt.xlim(0,20)
        plt.show()
    x0 = np.mean(eps[180:260])
    print('value of x0 is %.2f' % x0)

# %%
outdir = r'N:\Singlem\singlem19-4\November\15_CD95_NB_NV\all\chisurf'

files = os.listdir(outdir)

D0_3dat = np.genfromtxt(os.path.join(outdir, 'Donly3_G.dat'))
dtime = 0.064

for file in files:
    #skip non-green files and Donly files
    if file[-6:] != '_G.dat' or file[:5] == 'Donly':
        continue
    print('analyzing file %s' % file)
    DAdat = np.genfromtxt( os.path.join(outdir, file))
    epsilon(DAdat, D0dat)
# Out:
# analyzing file CD95-DeltaDD+L10_G.dat
# value of x0 is 0.85
# analyzing file CD95-DeltaDD+L11_G.dat
# value of x0 is 1.13
# analyzing file CD95-DeltaDD+L12_G.dat
# value of x0 is 0.68
# analyzing file CD95-DeltaDD+L13_G.dat
# value of x0 is 0.55
# analyzing file CD95-DeltaDD+L14_G.dat
# value of x0 is 1.50
# analyzing file CD95-DeltaDD+L15_G.dat
# value of x0 is 0.71
# analyzing file CD95-DeltaDD+L16_G.dat
# value of x0 is 1.77
# analyzing file CD95-DeltaDD+L17_G.dat
# value of x0 is 2.16
# analyzing file CD95-DeltaDD+L1_G.dat
# value of x0 is 0.91
# analyzing file CD95-DeltaDD+L2_G.dat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-ba44dbd4bcc7> in <module>
#      12     print('analyzing file %s' % file)
#      13     DAdat = np.genfromtxt( os.path.join(outdir, file))
# ---> 14     epsilon(DAdat, D0dat)
#
# <ipython-input-65-2986b0fcf02e> in epsilon(DAdat, D0dat, bgrange, makeplot, dtime)
#      17         plt.ylim(0.1,1.1)
#      18         plt.xlim(0,20)
# ---> 19         plt.show()
#      20     x0 = np.mean(eps[180:260])
#      21     print('value of x0 is %.2f' % x0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <C:\ProgramData\Anaconda3\lib\site-packages\decorator.py:decorator-gen-9> in __call__(self, obj)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2365
#    2366         for a in artists:
# -> 2367             bbox = a.get_tightbbox(renderer)
#    2368             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2369                 bb.append(bbox)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4357                 bb.append(bb_xaxis)
#    4358
# -> 4359             bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4360             if bb_yaxis:
#    4361                 bb.append(bb_yaxis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1162         ticks_to_draw = self._update_ticks()
#    1163
# -> 1164         self._update_label_position(renderer)
#    1165
#    1166         # go back to just this axis's tick labels
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2306         # get bounding boxes for this axis and any siblings
#    2307         # that have been set by `fig.align_ylabels()`
# -> 2308         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2309
#    2310         x, y = self.label.get_position()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    2290         # if we want to align labels from other axes:
#    2291         for axx in grp.get_siblings(self.axes):
# -> 2292             ticks_to_draw = axx.yaxis._update_ticks()
#    2293             tlb, tlb2 = axx.yaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2294             bboxes.extend(tlb)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1077         the axes.  Return the list of ticks that will be drawn.
#    1078         """
# -> 1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
#    1081         major_ticks = self.get_major_ticks(len(major_locs))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in get_majorticklocs(self)
#    1322     def get_majorticklocs(self):
#    1323         """Get the array of major tick locations in data coordinates."""
# -> 1324         return self.major.locator()
#    1325
#    1326     def get_minorticklocs(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2269         'Return the locations of the ticks'
#    2270         vmin, vmax = self.axis.get_view_interval()
# -> 2271         return self.tick_values(vmin, vmax)
#    2272
#    2273     def tick_values(self, vmin, vmax):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2274         if self.numticks == 'auto':
#    2275             if self.axis is not None:
# -> 2276                 numticks = np.clip(self.axis.get_tick_space(), 2, 9)
#    2277             else:
#    2278                 numticks = 9
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2487         ends = self.axes.transAxes.transform([[0, 0], [0, 1]])
#    2488         length = ((ends[1][1] - ends[0][1]) / self.axes.figure.dpi) * 72
# -> 2489         tick = self._get_tick(True)
#    2490         # Having a spacing of at least 2 just looks good.
#    2491         size = tick.label1.get_size() * 2.0
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2220         else:
#    2221             tick_kw = self._minor_tick_kw
# -> 2222         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2223
#    2224     def _get_label(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     581                           markersize=self._size,
#     582                           markeredgewidth=self._width,
# --> 583                           zorder=self._zorder)
#     584         l.set_transform(self.axes.get_yaxis_transform(which='tick1'))
#     585         self._set_artist_props(l)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickleft(self)
#     747
#     748     def _set_tickleft(self):
# --> 749         self._transform = Affine2D().scale(-1.0, 1.0)
#     750         self._snap_threshold = 1.0
#     751         self._filled = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# KeyboardInterrupt:

# %%
from scipy.optimize import curve_fit

# %%
def Donly(t, A, B, tau1, tau2, bg):
    return A * np.exp(-t/tau1) + B * np.exp(-t/tau2) + bg
def DA(t, A, x0, kf, D0):
    return A * ( (1-x0) * D0 * np.exp(-kf * t) + x0 * D0)
def fitDonly(D0dat):
    Npoints = D0dat.shape[0]
    fittime = np.arange(Npoints) * dtime
    p0 = [np.max(D0dat)/2, np.max(D0dat)/2, 1, 3, 1000]
    popt, pcov = curve_fit(Donly, fittime, D0dat, p0 = p0, sigma = np.sqrt(D0dat))
    Donlymodel = Donly(fittime, popt[0], popt[1], popt[2], popt[3], popt[4])
    Donly_base = Donly(fittime, popt[0] / ( popt[0] + popt[1] ), \
                            popt[1]/ ( popt[0] + popt[1]), popt[2], popt[3], 0)
    chi2red = np.sum( (D0dat-Donlymodel)**2 / D0dat) / (Npoints - 5)
    print('chi2 reduced is %.2f' % chi2red)
    return popt, pcov, Donly_base, Donlymodel, chi2red

# %%
# Out:
# chi2 reduced is 1.11

# %%
def fitDA (DAdat, D0dat):
    _, _, Donly_base, _, _ = fitDonly(D0dat)
    Npoints = D0dat.shape[0]
    fittime = np.arange(Npoints) * dtime
    p0 = [np.max(DAdat), 0.5, 2]
    popt, pcov = curve_fit( lambda t, A, x0, kf: DA(t, A, x0, kf, Donly_base), \
                           fittime, DAdat, p0 = p0, sigma = np.sqrt(DAdat) )
    DAmodel = DA()
    return popt, pcov

# %%
D0dat = D0_3dat[30:600,1]
popt, pcov, Donly_base, _, _ = fitDonly(D0dat)
file = files[0]
DAdat = np.genfromtxt( os.path.join(outdir, file))[30:600,1]
fitDA(DAdat, D0dat)
# Out:
# chi2 reduced is 1.11
# chi2 reduced is 1.11
# (array([1.74205349e+04, 9.62113432e-01, 1.46493644e+00]),
#  array([[ 2.96194974e+05, -1.46487689e+01,  9.15950223e+02],
#         [-1.46487689e+01,  9.21476506e-04, -2.66443693e-02],
#         [ 9.15950223e+02, -2.66443693e-02,  6.88620366e+00]]))

# %%
plt.plot(DA(fittime, np.max(DAdat), 0.5, 2, Donly_base), 'r--')
plt.plot(DAdat)

# %%
plt.plot(Donly_base)
