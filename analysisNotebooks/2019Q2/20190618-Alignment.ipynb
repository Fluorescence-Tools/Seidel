# %% [markdown]
# ## FRC was used to judge the spatial frequency content before and after alignment

# %%
import numpy as np
from PIL import Image
import os
from FRCfuncs import *

# %%
wdir = r'N:\Singlem\singlem19-2\June\18_alignment_check_STED_JHB_NV\FRC_before_alignment'

# %%
fname = os.path.join(wdir, r'Ch1\ImA.tif')
imA = genArrfromTif(fname)
fname = os.path.join(wdir, r'Ch1\ImB.tif')
imB = genArrfromTif(fname)
*_, smallAngleRes, LargeAngleRes = FRCAnalysis(imA, imB, 50, theta = np.pi/4, title = 'before alignment, Channel 1',
                                              correctDrift = False)
print('resolution for x is %.0f nm' % smallAngleRes[1,0])
print('resolution for y is %.0f nm' % LargeAngleRes[1,0])
# Out:
# retrieved resolution for before alignment, Channel 1 is: 294nm
#
# resolution for x is 286 nm
# resolution for y is 333 nm

# %%
Hm = Hamming (400,400)
plt.imshow(np.log(abs(np.fft.fftshift(np.fft.fft2(imA*Hm)))))

# %%
wdir = r'N:\Singlem\singlem19-2\June\18_alignment_check_STED_JHB_NV\FRC_before_alignment'
fname = os.path.join(wdir, r'Ch3\ImA.tif')
imA = genArrfromTif(fname)
fname = os.path.join(wdir, r'Ch3\ImB.tif')
imB = genArrfromTif(fname)
*_, smallAngleRes, LargeAngleRes = FRCAnalysis(imA, imB, 50, theta = 1, title = 'before alignment, Channel 3', 
                                               correctDrift = False)
print('resolution for x is %.0f nm' % smallAngleRes[1,0])
print('resolution for y is %.0f nm' % LargeAngleRes[1,0])
plt.savefig('20190618FRCBeforeAlignment.png', dpi = 300)
# Out:
# retrieved resolution for before alignment, Channel 3 is: 256nm
#
# resolution for x is 286 nm
# resolution for y is 339 nm

# %%
FRCAnalysis?

# %%
Hm = Hamming (400,400)
plt.imshow(np.log(abs(np.fft.fftshift(np.fft.fft2(imA*Hm))[100:300,100:300])))

# %%
wdir = r'N:\Singlem\singlem19-2\June\18_alignment_check_STED_JHB_NV\FRC_after_alignment'
fname = os.path.join(wdir, r'Ch1\ImA.tif')
imA = genArrfromTif(fname)
fname = os.path.join(wdir, r'Ch1\ImB.tif')
imB = genArrfromTif(fname)
*_, smallAngleRes, LargeAngleRes = FRCAnalysis(imA, imB, 50, theta = np.pi/4, title = 'after alignment, Channel 1',
                                              correctDrift = False)
print('resolution for x is %.0f nm' % smallAngleRes[1,0])
print('resolution for y is %.0f nm' % LargeAngleRes[1,0])
# Out:
# retrieved resolution for after alignment, Channel 1 is: 317nm
#
# resolution for x is 303 nm
# resolution for y is 339 nm

# %%
Hm = Hamming (400,400)
plt.imshow(np.log(abs(np.fft.fftshift(np.fft.fft2(imA*Hm))[100:300,100:300])))

# %%
wdir = r'N:\Singlem\singlem19-2\June\18_alignment_check_STED_JHB_NV\FRC_before_alignment'
fname = os.path.join(wdir, r'Ch3\ImA.tif')
imA = genArrfromTif(fname)
fname = os.path.join(wdir, r'Ch3\ImB.tif')
imB = genArrfromTif(fname)
*_, smallAngleRes, LargeAngleRes = FRCAnalysis(imA, imB, 50, theta = 1, title = 'before alignment, Channel 3', 
                                               correctDrift = False)
print('resolution for x is %.0f nm' % smallAngleRes[1,0])
print('resolution for y is %.0f nm' % LargeAngleRes[1,0])
# Out:
# retrieved resolution for before alignment, Channel 3 is: 256nm
#
# resolution for x is 286 nm
# resolution for y is 339 nm

# %%
wdir = r'N:\Singlem\singlem19-2\June\18_alignment_check_STED_JHB_NV\FRC_after_alignment'
fname = os.path.join(wdir, r'Ch3\ImA.tif')
imA = genArrfromTif(fname)
fname = os.path.join(wdir, r'Ch3\ImB.tif')
imB = genArrfromTif(fname)
*_, smallAngleRes, LargeAngleRes = FRCAnalysis(imA, imB, 50, theta = 1, title = 'after alignment, Channel 3', 
                                               correctDrift = False)
print('resolution for x is %.0f nm' % smallAngleRes[1,0])
print('resolution for y is %.0f nm' % LargeAngleRes[1,0])
# Out:
# retrieved resolution for after alignment, Channel 3 is: 351nm
#
# resolution for x is 308 nm
# resolution for y is 357 nm

# %%
Hm = Hamming (400,400)
plt.imshow(np.log(abs(np.fft.fftshift(np.fft.fft2(imA*Hm))[100:300,100:300])))
