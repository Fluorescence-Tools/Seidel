# %%
import developmental_functions as df
import numpy as np
import matplotlib.pyplot as plt
import os
from lmfit import fit_report
from scipy.optimize import minimize
import timeit
from importlib import reload
import utility

# %%
rootdir = r'N:\Singlem\singlem20-2\April\29_db_lowFRET_JHB'
wdir = os.path.join(rootdir, 'Analysis_JHB')
resdir = os.path.join(rootdir, 'analysis_NV')
identifier = 'dBLF29Apr'
outname = os.path.join(resdir, identifier + '.spots')
options = df.GAP.optionsCluster(fitbg = 0, setbg = 0.)
#file 1632 has read access restriction
files = os.listdir(wdir)[:1630] + os.listdir(wdir)[1634:]
LF29Apr = df.analyseDir(options, wdir, files, Ggate = 25, Rgate = 25, Ygate = 25,
                             outname = outname, framestop = -1, ROIsize = 20, verbose = False,
                        gateStop = 100, junkIstar = 0.40, garbageBrightness = 50, DTwoIstar = 0.05)
# Out:
# ['Overview_Pos_y-0.00140268_spot_0_x_-124.0_y_-160.0.ptu', 'Overview_Pos_y-0.00140268_spot_1_x_-20.0_y_-153.0.ptu', 'Overview_Pos_y-0.00140268_spot_10_x_137.0_y_-153.0.ptu', 'Overview_Pos_y-0.00140268_spot_11_x_138.0_y_-153.0.ptu', 'Overview_Pos_y-0.00140268_spot_12_x_138.0_y_-152.0.ptu', 'Overview_Pos_y-0.00140268_spot_13_x_-95.0_y_-149.0.ptu', 'Overview_Pos_y-0.00140268_spot_14_x_4.0_y_-148.0.ptu', 'Overview_Pos_y-0.00140268_spot_15_x_31.0_y_-147.0.ptu', 'Overview_Pos_y-0.00140268_spot_16_x_41.0_y_-144.0.ptu', 'Overview_Pos_y-0.00140268_spot_17_x_-5.0_y_-141.0.ptu', 'Overview_Pos_y-0.00140268_spot_18_x_-60.0_y_-136.0.ptu', 'Overview_Pos_y-0.00140268_spot_19_x_89.0_y_-115.0.ptu', 'Overview_Pos_y-0.00140268_spot_2_x_121.0_y_-110.0.ptu', 'Overview_Pos_y-0.00140268_spot_20_x_-116.0_y_-109.0.ptu', 'Overview_Pos_y-0.00140268_spot_21_x_61.0_y_-108.0.ptu', 'Overview_Pos_y-0.00140268_spot_22_x_-117.0_y_-107.0.ptu', 'Overview_Pos_y-0.00140268_spot_23_x_-88.0_y_-106.0.ptu', 'Overview_Pos_y-0.00140268_spot_24_x_-86.0_y_-106.0.ptu', 'Overview_Pos_y-0.00140268_spot_25_x_-117.0_y_-105.0.ptu', 'Overview_Pos_y-0.00140268_spot_26_x_-58.0_y_-101.0.ptu', 'Overview_Pos_y-0.00140268_spot_27_x_24.0_y_-91.0.ptu', 'Overview_Pos_y-0.00140268_spot_28_x_-100.0_y_-72.0.ptu', 'Overview_Pos_y-0.00140268_spot_29_x_-127.0_y_-55.0.ptu', 'Overview_Pos_y-0.00140268_spot_3_x_-25.0_y_-53.0.ptu', 'Overview_Pos_y-0.00140268_spot_30_x_155.0_y_-52.0.ptu', 'Overview_Pos_y-0.00140268_spot_31_x_57.0_y_-45.0.ptu', 'Overview_Pos_y-0.00140268_spot_32_x_110.0_y_-42.0.ptu', 'Overview_Pos_y-0.00140268_spot_33_x_156.0_y_-24.0.ptu', 'Overview_Pos_y-0.00140268_spot_34_x_-137.0_y_-23.0.ptu', 'Overview_Pos_y-0.00140268_spot_35_x_-93.0_y_-22.0.ptu', 'Overview_Pos_y-0.00140268_spot_36_x_-93.0_y_-19.0.ptu', 'header', 'Overview_Pos_y-0.00140268_spot_37_x_-172.0_y_-17.0.ptu', 'Overview_Pos_y-0.00140268_spot_38_x_46.0_y_-10.0.ptu', 'Overview_Pos_y-0.00140268_spot_39_x_-48.0_y_-1.0.ptu', 'Overview_Pos_y-0.00140268_spot_4_x_92.0_y_1.0.ptu', 'Overview_Pos_y-0.00140268_spot_40_x_91.0_y_2.0.ptu', 'Overview_Pos_y-0.00140268_spot_41_x_93.0_y_3.0.ptu', 'Overview_Pos_y-0.00140268_spot_42_x_-111.0_y_11.0.ptu', 'Overview_Pos_y-0.00140268_spot_43_x_11.0_y_11.0.ptu', 'Overview_Pos_y-0.00140268_spot_44_x_-138.0_y_25.0.ptu', 'Overview_Pos_y-0.00140268_spot_45_x_130.0_y_25.0.ptu', 'Overview_Pos_y-0.00140268_spot_46_x_-61.0_y_35.0.ptu', 'Overview_Pos_y-0.00140268_spot_47_x_-136.0_y_58.0.ptu', 'Overview_Pos_y-0.00140268_spot_48_x_103.0_y_74.0.ptu', 'Overview_Pos_y-0.00140268_spot_49_x_-70.0_y_81.0.ptu', 'Overview_Pos_y-0.00140268_spot_5_x_133.0_y_81.0.ptu', 'Overview_Pos_y-0.00140268_spot_50_x_-13.0_y_82.0.ptu', 'Overview_Pos_y-0.00140268_spot_51_x_-137.0_y_126.0.ptu', 'Overview_Pos_y-0.00140268_spot_52_x_120.0_y_131.0.ptu', 'Overview_Pos_y-0.00140268_spot_53_x_15.0_y_134.0.ptu', 'Overview_Pos_y-0.00140268_spot_54_x_13.0_y_137.0.ptu', 'Overview_Pos_y-0.00140268_spot_55_x_-91.0_y_140.0.ptu', 'Overview_Pos_y-0.00140268_spot_56_x_-47.0_y_145.0.ptu', 'Overview_Pos_y-0.00140268_spot_6_x_71.0_y_154.0.ptu', 'Overview_Pos_y-0.00140268_spot_7_x_-21.0_y_155.0.ptu', 'Overview_Pos_y-0.00140268_spot_8_x_70.0_y_155.0.ptu', 'Overview_Pos_y-0.00140268_spot_9_x_146.0_y_167.0.ptu', 'Overview_Pos_y-0.00142468_spot_0_x_48.0_y_-161.0.ptu', 'Overview_Pos_y-0.00142468_spot_1_x_49.0_y_-161.0.ptu', 'Overview_Pos_y-0.00142468_spot_10_x_123.0_y_-155.0.ptu', 'Overview_Pos_y-0.00142468_spot_11_x_16.0_y_-133.0.ptu', 'Overview_Pos_y-0.00142468_spot_12_x_59.0_y_-130.0.ptu', 'Overview_Pos_y-0.00142468_spot_13_x_124.0_y_-126.0.ptu', 'Overview_Pos_y-0.00142468_spot_14_x_-47.0_y_-114.0.ptu', 'Overview_Pos_y-0.00142468_spot_15_x_-149.0_y_-105.0.ptu', 'Overview_Pos_y-0.00142468_spot_16_x_-83.0_y_-99.0.ptu', 'Overview_Pos_y-0.00142468_spot_17_x_171.0_y_-99.0.ptu', 'Overview_Pos_y-0.00142468_spot_18_x_106.0_y_-94.0.ptu', 'Overview_Pos_y-0.00142468_spot_19_x_14.0_y_-89.0.ptu', 'Overview_Pos_y-0.00142468_spot_2_x_158.0_y_-71.0.ptu', 'Overview_P ...
# analysing image no. 0
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_0_x_-124.0_y_-160.0.txt'
# number of records is 110322
# K:\vanderVoortN\FRC\Code\GaussAnalysisPipeline.py:186: RuntimeWarning: invalid value encountered in greater
#   isNoJunkIstar = twoIstar > junkIstar
# K:\vanderVoortN\FRC\Code\GaussAnalysisPipeline.py:191: RuntimeWarning: invalid value encountered in less
#   isSignificantlyLower[i] = (twoIstar[i] + DTwoIstar < twoIstar[: i]).all()
# analysing image no. 1
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_1_x_-20.0_y_-153.0.txt'
# number of records is 119241
# analysing image no. 2
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_10_x_137.0_y_-153.0.txt'
# number of records is 110199
# analysing image no. 3
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_11_x_138.0_y_-153.0.txt'
# number of records is 109874
# analysing image no. 4
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_12_x_138.0_y_-152.0.txt'
# number of records is 117343
# analysing image no. 5
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_13_x_-95.0_y_-149.0.txt'
# number of records is 111311
# analysing image no. 6
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_14_x_4.0_y_-148.0.txt'
# number of records is 109725
# analysing image no. 7
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_15_x_31.0_y_-147.0.txt'
# number of records is 106198
# analysing image no. 8
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_16_x_41.0_y_-144.0.txt'
# number of records is 117577
# analysing image no. 9
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_17_x_-5.0_y_-141.0.txt'
# number of records is 108026
# analysing image no. 10
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_18_x_-60.0_y_-136.0.txt'
# number of records is 106105
# analysing image no. 11
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_19_x_89.0_y_-115.0.txt'
# number of records is 110451
# analysing image no. 12
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_2_x_121.0_y_-110.0.txt'
# number of records is 112521
# analysing image no. 13
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_20_x_-116.0_y_-109.0.txt'
# number of records is 106286
# analysing image no. 14
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_21_x_61.0_y_-108.0.txt'
# number of records is 117183
# analysing image no. 15
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_22_x_-117.0_y_-107.0.txt'
# number of records is 109404
# analysing image no. 16
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_23_x_-88.0_y_-106.0.txt'
# number of records is 110395
# analysing image no. 17
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_24_x_-86.0_y_-106.0.txt'
# number of records is 118070
# analysing image no. 18
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_25_x_-117.0_y_-105.0.txt'
# number of records is 107227
# analysing image no. 19
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_26_x_-58.0_y_-101.0.txt'
# number of records is 112029
# analysing image no. 20
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_27_x_24.0_y_-91.0.txt'
# number of records is 113182
# analysing image no. 21
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_28_x_-100.0_y_-72.0.txt'
# number of records is 113059
# analysing image no. 22
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_29_x_-127.0_y_-55.0.txt'
# number of records is 109968
# analysing image no. 23
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_3_x_-25.0_y_-53.0.txt'
# number of records is 108190
# analysing image no. 24
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_30_x_155.0_y_-52.0.txt'
# number of records is 105844
# analysing image no. 25
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_31_x_57.0_y_-45.0.txt'
# number of records is 106943
# analysing image no. 26
# header dir already exists
# b'N:\\Singlem\\singlem20-2\\April\\29_db_lowFRET_JHB\\Analysis_JHB\\header\\Overview_Pos_y-0.00140268_spot_32_x_110.0_y_-42.0.txt'
# number of records is 115237
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4f9f82396af6> in <module>
#      10 LF29Apr = df.analyseDir(options, wdir, files, Ggate = 25, Rgate = 25, Ygate = 25,
#      11                              outname = outname, framestop = -1, ROIsize = 20, verbose = False,
# ---> 12                         gateStop = 100, junkIstar = 0.40, garbageBrightness = 50, DTwoIstar = 0.05)
#
# K:\vanderVoortN\FRC\Code\developmental_functions.py in analyseDir(options, wdir, files, Ggate, Rgate, Ygate, DTwoIstar, garbageBrightness, junkIstar, outname, framestop, ntacs, ROIsize, rebin, verbose, saveplot, min_distance, ROI_threshold_rel, ROI_threshold_abs, gateStop)
#     127                     snip, options,
#     128                     DTwoIstar = DTwoIstar, garbageBrightness = garbageBrightness,
# --> 129                     junkIstar = junkIstar, verbose = verbose, outdir = outdir
#     130                     )
#     131                 #this function appends each time it is called
#
# K:\vanderVoortN\FRC\Code\GaussAnalysisPipeline.py in fitNGauss(image, OptionsCluster, DTwoIstar, garbageBrightness, junkIstar, verbose, outdir)
#     126     param3Gauss = GaussFits.Fit2DGauss(param3Gauss, image)
#     127
# --> 128     if verbose or outdir:
#     129         outfile = os.path.join(outdir, 'contourfits.png')
#     130         fig, axs = plt.subplots(1,3, figsize = (12,3))
#
# KeyboardInterrupt:

# %%
df.plotOccurence(LF29Apr)
# Out:
# array([[250, 349,  28,   3,   0,   1],
#        [194, 741,  91,  10,   1,   0],
#        [ 26, 113,  57,  10,   0,   0],
#        [  2,  24,  10,   2,   0,   0],
#        [  0,   1,   1,   2,   1,   0],
#        [  0,   0,   0,   1,   0,   0]])

# %%
locfile = os.path.join(resdir, identifier  + '.spots')
anfile = os.path.join(resdir, identifier + '_an.spots')
load = True
if load:
    dBLF29Apr = df.loadpickle(locfile)
    dBLF29Apr_an = df.loadpickle(anfile)
    dBLF29Apr_stats = df.genStats(dBLF29Apr_an)
else:
    dBLF29Apr_an, dBLF29Apr_stats = utility.analyzeRuler1D1A(dBLF29Apr, resdir, identifier)

# %%
maxval = 60

outdir = os.path.join(resdir, 'chifit')
data = dBLF29Apr_an
datas = df.filterFRETind(data, 'stoichiometry', 0.2, 0.8)

datas = df.filterFRETind(datas, 'NG', 50, 1000)
datas = df.filterFRETind(datas, 'NY', 100, 1000)

fstats = df.genStats(datas)
#fstats = df.filterStats(fstats, 'sigmaY', 1.5, 2.5)
#fstats = df.filterStats(fstats, 'sigmaG', 0, 3.3)
plt.plot(fstats['distx'], fstats['disty'], 'o', alpha = 0.5)
plt.xlim(-30, 30)
plt.ylim(-30, 30)
plt.xlabel('dist x (nm)')
plt.ylabel('dist y (nm)')
plt.show()


dist = np.array((fstats['distx'], fstats['disty'])).transpose()
#dist = df.filterVec(dist, maxval = maxval, center = [5,0])
dist = df.filterVec(dist, maxval = maxval)
distnorm = np.linalg.norm(dist, axis = 1)
outfile = os.path.join(outdir, identifier + r'_distdict.txt')
distDict = {}
distDict ['distx'] = dist[:,0]
distDict ['disty'] = dist[:,1]
distDict['distnorm'] = distnorm
df.saveDict(distDict, outfile)


modelout = os.path.join(outdir, identifier + r'_chiFit.txt')
plotout = os.path.join(outdir, identifier + r'_subpopulation.png')

TACout = os.path.join(outdir, 'filterTAC\\' + identifier + '_cut.txt')
df.subensembleTAC(datas, outfile = TACout)

dist = distnorm
maxbin = maxval
binwidth = 1
counts, bin_edges, _ = plt.hist(dist, bins = np.arange(0, maxbin, binwidth))
plt.clf()
Nbins = bin_edges.shape[0] - 1
bins = np.zeros(Nbins)
for i in range(Nbins):
    bins[i] = (bin_edges[i] + bin_edges[i + 1]) / 2


fitres = df.whichChiIsBest(bins, counts, verbose = True)
print(fit_report(fitres))
df.plotdistr(distnorm, bins, fit = fitres , title = identifier, 
                           modelout = modelout, plotout = plotout)
p = df.genPeakEst(1, counts, bins)
p['bg'].set(vary = True, value = 0)
p['mu0'].set(vary = True, value = 0)
#p['mu0'].set(vary = False, value = 7.1)
#p['sig0'].set(vary = False, value = 4.6)
fitres2, AIC, *_ = df.fitNChidistr(p, bins, counts)

modelout = os.path.join(outdir, identifier + r'_singlechi_mu0.txt')
plotout = os.path.join(outdir, identifier + r'_singlechi_mu0.png')
df.plotdistr(distnorm, bins, fit = fitres2 , title = identifier + '_singlechi_mu0', 
                           modelout = modelout, plotout = plotout)
print(fit_report(fitres2))
print('AIC for mu fixed to 0 os %.1f' % AIC)
p = df.genPeakEst(2, counts, bins)
p['bg'].set(vary = True, value = 0)
p['mu0'].set(vary = True, value = 0)
p['sig0'].set(vary = True, value = 3.5)
#p['A0'].set(vary = True, value = 150)
#p['mu1'].set(vary = False, value = 7)
#p['sig1'].set(vary = False, value = 2)
#p['mu2'].set(vary = True, value = 5)
#p['sig2'].set(vary = True, value = 12)
fitres3, AIC, *_ = df.fitNChidistr(p, bins, counts)

modelout = os.path.join(outdir, identifier + r'_2chiFit.txt')
plotout = os.path.join(outdir, identifier + r'_2chiFit.png')
df.plotdistr(distnorm, bins, fit = fitres3 , title = identifier + '  - double chi', 
                           modelout = modelout, plotout = plotout)
print(fit_report(fitres3))
print('AIC for 2chi distributions is %.1f' % AIC)

outname = os.path.join (outdir, 'single_Chi_components.csv')
df.exportChiComponents(outname, bins, fitres3.params)

p = df.genPeakEst(2, counts, bins)
p['bg'].set(vary = True, value = 0)
p['mu0'].set(vary = False, value = 0)
p['sig0'].set(vary = True, value = 3.5)
#p['A0'].set(vary = True, value = 150)
#p['mu1'].set(vary = False, value = 7)
#p['sig1'].set(vary = False, value = 2)
#p['mu2'].set(vary = True, value = 5)
#p['sig2'].set(vary = True, value = 12)
fitres4, AIC, *_ = df.fitNChidistr(p, bins, counts)

modelout = os.path.join(outdir, identifier + r'_2chiFit_mu0.txt')
plotout = os.path.join(outdir, identifier + r'_2chiFit_mu0.png')
df.plotdistr(distnorm, bins, fit = fitres4, title = identifier + '  - double chi mu0 pop', 
                           modelout = modelout, plotout = plotout)
print(fit_report(fitres3))
print('AIC for 2chi distributions is %.1f' % AIC)

p = df.genPeakEst(1, counts, bins)
p['bg'].set(vary = False, value = 0)
p['mu0'].set(vary = False, value = 12)
p['sig0'].set(vary = False, value = 3.5)
p['A0'].set(vary= False, value = 400)
dummy_fit = fitres4
dummy_fit.params = p
modelout = os.path.join(outdir, identifier + r'_expected_distribution.txt')
plotout = os.path.join(outdir, identifier + r'_expected_distribution.png')
df.plotdistr(distnorm, bins, dummy_fit, title = identifier + ' - expected distribution',
            modelout = modelout, plotout = plotout)

p = df.genPeakEst(2, counts, bins)
p['bg'].set(vary = False, value = 0)
p['mu0'].set(vary = False, value = 12)
p['sig0'].set(vary = False, value = 3.5)
p['A0'].set(vary= True, value = 500)
p['mu1'].set(vary = True, value = 12)
p['sig1'].set(vary = False, value = 3.5)
p['A1'].set(vary= True, value = 500)
fitres5, AIC, *_, ll = df.fitNChidistr(p, bins, counts)
modelout = os.path.join(outdir, identifier + r'_expected+mid_distribution.txt')
plotout = os.path.join(outdir, identifier + r'_expected+mid_distribution.png')
df.plotdistr(distnorm, bins, fitres5, title = identifier + ' - expected + 1 free distribution',
            modelout = modelout, plotout = plotout)
print(fit_report(fitres5))
print('AIC for expected + 1 free distribution is %.1f' % AIC)
print('log-likelihood is ' + str(ll))


plt.plot(fstats['tauG'], fstats['proxRatio'], '.')
fitres
# Out:
# 6.4 in x and -0.6 in y subtracted
# fit for 3 peaks failed
# AIC is 1237.2 for 0 peaks
# AIC is 147.9 for 1 peaks
# AIC is 148.1 for 2 peaks
# BIC is 1241.4 for 0 peaks
# BIC is 164.5 for 1 peaks
# BIC is 177.2 for 2 peaks
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 186
#     # data points      = 1
#     # variables        = 4
#     chi-square         = 4895.17966
#     reduced chi-square = 4895.17966
#     Akaike info crit   = 16.4960063
#     Bayesian info crit = 8.49600626
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     bg:    0.03517180 (init = 0.7966102)
#     mu0:   8.66068534 (init = 10.35319)
#     A0:    467.744501 (init = 470)
#     sig0:  5.03987598 (init = 4.591127)
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 168
#     # data points      = 1
#     # variables        = 4
#     chi-square         = 6873.76109
#     reduced chi-square = 6873.76109
#     Akaike info crit   = 16.8354667
#     Bayesian info crit = 8.83546670
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     bg:    3.6840e-09 (init = 0)
#     mu0:   0.11677742 (init = 0)
#     A0:    469.697284 (init = 1740.5)
#     sig0:  8.01054182 (init = 8.661726)
# AIC for mu fixed to 0 os 173.8
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 936
#     # data points      = 1
#     # variables        = 7
#     chi-square         = 4895.17965
#     reduced chi-square = 4895.17965
#     Akaike info crit   = 22.4960063
#     Bayesian info crit = 8.49600625
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     bg:    0.03516881 (init = 0)
#     mu0:   0.10702828 (init = 0)
#     A0:    2.5703e-07 (init = 1740.5)
#     sig0:  4.26824665 (init = 3.5)
#     mu1:   8.66085211 (init = 2.795748)
#     A1:    467.753506 (init = 1740.5)
#     sig1:  5.03986762 (init = 8.661726)
# AIC for 2chi distributions is 153.9
# Parameters([('bg', <Parameter 'bg', value=0 (fixed), bounds=[0:10]>), ('mu0', <Parameter 'mu0', value=0.10702827584501845, bounds=[0:58.5]>), ('sig0', <Parameter 'sig0', value=4.268246651117794, bounds=[0:inf]>), ('A0', <Parameter 'A0', value=2.570306273375067e-07, bounds=[0:17405.0]>)])
# Parameters([('bg', <Parameter 'bg', value=0 (fixed), bounds=[0:10]>), ('mu0', <Parameter 'mu0', value=8.66085211042003, bounds=[0:58.5]>), ('sig0', <Parameter 'sig0', value=5.039867619729386, bounds=[0:inf]>), ('A0', <Parameter 'A0', value=467.7535061191169, bounds=[0:17405.0]>)])
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 936
#     # data points      = 1
#     # variables        = 7
#     chi-square         = 4895.17965
#     reduced chi-square = 4895.17965
#     Akaike info crit   = 22.4960063
#     Bayesian info crit = 8.49600625
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     bg:    0.03516881 (init = 0)
#     mu0:   0.10702828 (init = 0)
#     A0:    2.5703e-07 (init = 1740.5)
#     sig0:  4.26824665 (init = 3.5)
#     mu1:   8.66085211 (init = 2.795748)
#     A1:    467.753506 (init = 1740.5)
#     sig1:  5.03986762 (init = 8.661726)
# AIC for 2chi distributions is 151.9
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 164
#     # data points      = 1
#     # variables        = 3
#     chi-square         = 8224.90671
#     reduced chi-square = 8224.90671
#     Akaike info crit   = 15.0149222
#     Bayesian info crit = 9.01492223
# ##  Warning: uncertainties could not be estimated:
#     this fitting method does not natively calculate uncertainties
#     and numdifftools is not installed for lmfit to do this. Use
#     `pip install numdifftools` for lmfit to estimate uncertainties
#     with this fitting method.
# [[Variables]]
#     bg:    0 (fixed)
#     mu0:   12 (fixed)
#     A0:    253.874685 (init = 500)
#     sig0:  3.5 (fixed)
#     mu1:   6.34472525 (init = 12)
#     A1:    216.002337 (init = 500)
#     sig1:  3.5 (fixed)
# AIC for expected + 1 free distribution is 187.4
# log-likelihood is -90.69127140725308
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>Nelder-Mead</td><td></td></tr><tr><td># function evals</td><td>186</td><td></td></tr><tr><td># data points</td><td>1</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 4895.17966</td><td></td></tr><tr><td>reduced chi-square</td><td> 4895.17966</td><td></td></tr><tr><td>Akaike info crit.</td><td> 16.4960063</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 8.49600626</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> bg </td><td>  0.03517180 </td><td> 0.7966101694915254 </td><td>  0.00000000 </td><td>  4700.00000 </td><td> True </td></tr><tr><td> mu0 </td><td>  8.66068534 </td><td> 10.353191489361702 </td><td>  0.00000000 </td><td>  53.0000000 </td><td> True </td></tr><tr><td> A0 </td><td>  467.744501 </td><td> 470.0 </td><td>  0.00000000 </td><td>  4700.00000 </td><td> True </td></tr><tr><td> sig0 </td><td>  5.03987598 </td><td> 4.591127014274835 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %%
reload(df)
# Out:
# <module 'developmental_functions' from 'K:\\vanderVoortN\\FRC\\Code\\developmental_functions.py'>

# %%
param_ranges={"sig0":np.arange(1, 8, 0.2),"mu0":np.arange(0, 14,0.2)}
p = df.genPeakEst(1, counts, bins)
p['bg'].set(vary = True, value = 0)
p['mu0'].set(vary = True, value = 7)
p['sig0'].set(vary = True, value = 4)
p['A0'].set(vary = True, value = 350)
#p['mu1'].set(vary = True, value = 5)
#p['sig1'].set(vary = True, value = 10)
#p['A1'].set(vary = True, value = 400)
 
MFsurface = df.scanLikelihoodSurface(param_ranges, p, bins, counts)
outname = r'N:\Singlem\singlem20-2\April\29_db_lowFRET_JHB\analysis_NV\Likelihood_surface1Chi.png'
df.plotLikelihoodSurface(MFsurface, param_ranges, outname = outname, title = 'LF DNA Ruler', skip = 5)

# %%
max(MFsurface)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-95973fccb541> in <module>
# ----> 1 max(MFsurface)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
