# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from FRCfuncs import *
from scipy.optimize import curve_fit

# %%
t0 = time.time()
wdir = r'N:\Singlem\singlem19-1\February\21_FRC_NV_CG'
powers = np.arange(0,101,10)
#Data will be stored in a list. Each entry of list contains 3D image of type numpy array.
imStackLst = []
for power in powers:
    ext = r'PowerSeries\{0:d}pct_tac26-200\Red Photons'.format(power)
    filedir = os.path.join(wdir, ext)
    RedCh = readfolder(filedir)
    ext = r'PowerSeries\{0:d}pct_tac26-200\Green Photons'.format(power)
    filedir = os.path.join(wdir, ext)
    GreenCh = readfolder(filedir)
    imStackLst.append (RedCh + GreenCh)
t1 = time.time()
print ("computational time equals: " + str( t1 - t0))
# Out:
# computational time equals: 47.80313491821289

# %%
Nimg = len(powers)
FRC = np.zeros(Nimg)
Bleaching = np.zeros(Nimg)
BleachingSigma = np.zeros(Nimg)
for i, imStack in enumerate(imStackLst):
    power = powers[i]
    imA = np.sum(imStack[::2], axis = 0)
    imB = np.sum(imStack[1::2], axis =0)
    __, __, __, __, __, res = FRCAnalysis(imA, imB, 15, title = "FRC at " + str(power) + "% STED power")
    FRC[i] = res[0,0]
    frameint = np.sum(imStack, axis = (1,2))
    popt, pcov = fitBleaching (frameint, showFit = True)
    Bleaching[i] = np.log(2) * popt[1]
    BleachingSigma[i] = np.sqrt(pcov[1,1]) * np.log(2)
# Out:
# retrieved resolution for FRC at 0% STED power is: 111nm
# decay half-life is 159114.77 ± nan frames
# K:\vanderVoortN\FRC\python\Code\FRCfuncs.py:212: RuntimeWarning: invalid value encountered in sqrt
#   print (u'decay half-life is {0:.2f} \u00B1 {1:.2f} frames'.format(np.log(2) * popt[1],np.sqrt(pcov[1,1]) * np.log(2)))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in sqrt
# retrieved resolution for FRC at 10% STED power is: 94nm
# decay half-life is 16.86 ± 3.97 frames
# retrieved resolution for FRC at 20% STED power is: 77nm
# decay half-life is 1.49 ± 0.72 frames
# retrieved resolution for FRC at 30% STED power is: 73nm
# decay half-life is 92687.34 ± 90110051.18 frames
# retrieved resolution for FRC at 40% STED power is: 70nm
# decay half-life is 10.56 ± 2.47 frames
# retrieved resolution for FRC at 50% STED power is: 62nm
# decay half-life is 15.69 ± 2.39 frames
# retrieved resolution for FRC at 60% STED power is: 61nm
# decay half-life is 17.80 ± 1.80 frames
# retrieved resolution for FRC at 70% STED power is: 57nm
# decay half-life is 10.99 ± 1.51 frames
# retrieved resolution for FRC at 80% STED power is: 59nm
# decay half-life is 12.43 ± 3.18 frames
# retrieved resolution for FRC at 90% STED power is: 53nm
# decay half-life is 5.82 ± 0.74 frames
# retrieved resolution for FRC at 100% STED power is: 55nm
# decay half-life is 12.49 ± 1.52 frames

# %%
Bleaching
# Out:
# array([1.59114766e+05, 1.68601411e+01, 1.49101891e+00, 9.26873424e+04,
#        1.05639548e+01, 1.56881690e+01, 1.78032465e+01, 1.09855109e+01,
#        1.24345128e+01, 5.82470147e+00, 1.24945717e+01])

# %%
plt.errorbar(powers*10,Bleaching*3, yerr = BleachingSigma*3)
plt.xlabel('STED depletion power (mW)')
plt.ylabel(u'half life of fluorophore ( # scannes 5 \u00B5s each)')
plt.title('Tetraspeck bleaching half-life (multiple frames, 3 lines / frame)')
plt.show()

# %%
def inversesqrt(x, ConfocalRes, Is):
    return ConfocalRes/(1+np.sqrt(x)/Is)

def fitSTEDpower(STEDpower, STEDresolution, p0 = (240,10)):
    return curve_fit(inversesqrt, STEDpower, STEDresolution, p0 = p0)
popt, pcov = fitSTEDpower(STEDpowers, FRC)
fitFRC = inversesqrt(STEDpowers, popt[0], popt[1])

# %%
STEDpowers = powers*10
plt.plot(STEDpowers,FRC, '.-', label = 'FRC resolution')
plt.plot(STEDpowers, fitFRC, '--', label = 'fit A/(1 + I_STED / I_s)')
plt.xlabel('STED depletion power (mW)')
plt.ylabel('FRC resolution (nm)')
plt.title('Optimal STED depletion power imaging 40nm Crimson Beads')
plt.legend()
plt.savefig("40nmCrimsonSTEDpowerSeriesFRC.png", dpi = 300)
plt.show()

# %%
ext = r'TS_exc640_1perc_sted775_100perc_C1S3Ch26-56\Red Photons'
filedir = os.path.join(wdir, ext)
imStackA = readfolder (filedir)

ext = r'TS_exc640_1perc_sted775_100perc_C1S3Ch57-200\Red Photons'
filedir = os.path.join(wdir, ext)
imStackB = readfolder(filedir)

# %%
frameint = np.sum(imStackA + imStackB, axis = (1, 2))
fitBleaching (frameint, showFit = True)
# Out:
# decay half-life is 5.59 ± 0.31 frames
# (array([5.80644090e+03, 8.07175425e+00, 3.49836676e+04]),
#  array([[ 2.55438166e+04, -3.03869278e+01, -9.05693149e+02],
#         [-3.03869278e+01,  2.01368280e-01, -1.77879591e+01],
#         [-9.05693149e+02, -1.77879591e+01,  3.48121280e+03]]))

# %%
wdir = r'N:\Singlem\singlem19-1\February\21_FRC_NV_CG'
ext = r'Drifts analysis\Red Photons'
filedir = os.path.join(wdir, ext)
img = readfolder(filedir)
plotWindow = 10
imcenter = 125
pixelSize = 15
for i in range (49):
    imA = np.sum(img[i:i+1], axis = 0)
    imB = np.sum(img[i+1:i+2], axis = 0)
    DriftDetect(imA, imB, pixelSize, verbose = False, plotWindow = plotWindow)
    
imA = np.sum(img[0:1], axis = 0)
imB = np.sum(img[49:50], axis = 0)
DriftDetect(imA, imB, pixelSize, verbose = True, plotWindow = plotWindow)
# Out:
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# (250, 250)
# shift in x is  -0.663 ± 0.029  pixels
# shift in y is  0.095 ± 0.024 pixels
# total shift is 10.050 ± 0.037 nm for pixel size of 15 nm
# (array([124.33677375, 125.09522741]), array([0.02872359, 0.02372995]))
